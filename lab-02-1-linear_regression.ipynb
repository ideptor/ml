# %%
# Lab 2 Linear Regression
import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility
# Out:
# C:\Users\idept\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# X and Y data

x_train = [1,2,3]
y_train = [1,2,3]

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Our hypothesis WX_b
hypothesis = x_train * W + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
print("Step\tCost    \tW       \tb")


for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
#         print("{:04d}\t{:8.7f}\t{:8.7f}\t{:8.7f}".format(step, sess.run(cost), sess.run(W), sess.run(b)))
# Out:
# Step	Cost    	W       	b
# 0 2.2691786 [2.0574281] [-0.8804566]
# 20 0.18453546 [1.5261186] [-1.0509413]
# 40 0.15058567 [1.455534] [-1.0217243]
# 60 0.13660999 [1.4297589] [-0.97562784]
# 80 0.12406995 [1.4091458] [-0.9299597]
# 100 0.11268226 [1.3898778] [-0.88627225]
# 120 0.10233984 [1.3715514] [-0.84462243]
# 140 0.09294667 [1.3540895] [-0.8049285]
# 160 0.08441568 [1.3374486] [-0.7670998]
# 180 0.0766677 [1.3215897] [-0.73104894]
# 200 0.06963085 [1.3064764] [-0.69669235]
# 220 0.06323984 [1.292073] [-0.66395056]
# 240 0.057435483 [1.2783467] [-0.6327474]
# 260 0.05216381 [1.2652655] [-0.6030106]
# 280 0.047376007 [1.2527989] [-0.57467145]
# 300 0.043027636 [1.2409182] [-0.54766387]
# 320 0.03907838 [1.229596] [-0.52192557]
# 340 0.03549156 [1.2188057] [-0.49739686]
# 360 0.032234013 [1.2085227] [-0.474021]
# 380 0.029275438 [1.1987227] [-0.45174366]
# 400 0.026588446 [1.1893836] [-0.43051338]
# 420 0.024148053 [1.1804833] [-0.4102809]
# 440 0.021931635 [1.1720012] [-0.39099926]
# 460 0.019918667 [1.1639178] [-0.3726237]
# 480 0.01809046 [1.1562142] [-0.35511172]
# 500 0.01643004 [1.1488729] [-0.33842275]
# 520 0.014922012 [1.141876] [-0.3225181]
# 540 0.013552395 [1.1352085] [-0.30736083]
# 560 0.012308501 [1.1288542] [-0.292916]
# 580 0.011178787 [1.1227988] [-0.27915004]
# 600 0.010152757 [1.1170275] [-0.266031]
# 620 0.009220886 [1.1115277] [-0.2535285]
# 640 0.008374565 [1.1062863] [-0.24161364]
# 660 0.007605929 [1.1012913] [-0.23025876]
# 680 0.006907826 [1.0965309] [-0.21943745]
# 700 0.0062737823 [1.0919942] [-0.20912464]
# 720 0.0056979563 [1.0876709] [-0.19929647]
# 740 0.0051749693 [1.0835508] [-0.18993036]
# 760 0.0046999827 [1.079624] [-0.18100424]
# 780 0.0042686085 [1.0758821] [-0.1724977]
# 800 0.0038768174 [1.0723159] [-0.16439098]
# 820 0.0035209942 [1.0689174] [-0.15666528]
# 840 0.003197821 [1.0656785] [-0.1493026]
# 860 0.0029043166 [1.062592] [-0.142286]
# 880 0.0026377493 [1.0596502] [-0.1355992]
# 900 0.0023956408 [1.056847] [-0.12922648]
# 920 0.0021757672 [1.0541754] [-0.1231533]
# 940 0.0019760614 [1.0516293] [-0.11736555]
# 960 0.0017946843 [1.0492028] [-0.11184975]
# 980 0.0016299657 [1.0468905] [-0.10659319]
# 1000 0.0014803642 [1.0446869] [-0.1015837]
# 1020 0.0013444895 [1.0425868] [-0.09680968]
# 1040 0.0012210842 [1.0405854] [-0.09226005]
# 1060 0.0011090103 [1.0386778] [-0.08792406]
# 1080 0.0010072188 [1.0368601] [-0.08379193]
# 1100 0.00091477175 [1.0351279] [-0.07985403]
# 1120 0.0008308124 [1.033477] [-0.07610113]
# 1140 0.0007545569 [1.0319037] [-0.07252467]
# 1160 0.0006852971 [1.0304042] [-0.06911626]
# 1180 0.00062239653 [1.0289754] [-0.06586798]
# 1200 0.0005652692 [1.0276136] [-0.06277241]
# 1220 0.00051338814 [1.0263159] [-0.05982232]
# 1240 0.00046626432 [1.0250791] [-0.05701086]
# 1260 0.0004234739 [1.0239006] [-0.05433157]
# 1280 0.0003846034 [1.0227773] [-0.05177823]
# 1300 0.00034930444 [1.0217069] [-0.04934488]
# 1320 0.00031724604 [1.0206871] [-0.04702594]
# 1340 0.00028812993 [1.0197147] [-0.04481611]
# 1360 0.00026168313 [1.018788] [-0.04270982]
# 1380 0.00023766246 [1.017905] [-0.04070254]
# 1400 0.00021584831 [1.0170636] [-0.03878964]
# 1420 0.000196038 [1.0162617] [-0.0369667]
# 1440 0.00017804455 [1.0154974] [-0.0352294]
# 1460 0.00016170395 [1.0147691] [-0.03357372]
# 1480 0.00014686155 [1.014075] [-0.03199584]
# 1500 0.00013338173 [1.0134135] [-0.03049219]
# 1520 0.00012114024 [1.0127832] [-0.02905916]
# 1540 0.00011002049 [1.0121825] [-0.02769347]
# 1560 9.9921956e-05 [1.0116099] [-0.02639198]
# 1580 9.0751215e-05 [1.0110643] [-0.02515168]
# 1600 8.242363e-05 [1.0105444] [-0.02396972]
# 1620 7.4857126e-05 [1.0100486] [-0.02284319]
# 1640 6.798618e-05 [1.0095764] [-0.02176955]
# 1660 6.174543e-05 [1.0091264] [-0.02074643]
# 1680 5.6079076e-05 [1.0086975] [-0.01977144]
# 1700 5.0931132e-05 [1.0082887] [-0.01884228]
# 1720 4.6256126e-05 [1.0078992] [-0.01795674]
# 1740 4.2011932e-05 [1.007528] [-0.01711283]
# 1760 3.8155395e-05 [1.0071743] [-0.01630859]
# 1780 3.4653047e-05 [1.006837] [-0.01554216]
# 1800 3.1472486e-05 [1.0065156] [-0.01481172]
# 1820 2.8583965e-05 [1.0062095] [-0.01411559]
# 1840 2.5960324e-05 [1.0059177] [-0.01345223]
# 1860 2.3577697e-05 [1.0056396] [-0.01282005]
# 1880 2.1414038e-05 [1.0053746] [-0.01221756]
# 1900 1.9448204e-05 [1.005122] [-0.0116434]
# 1920 1.7662784e-05 [1.0048811] [-0.01109617]
# 1940 1.6041433e-05 [1.0046519] [-0.0105747]
# 1960 1.4570018e-05 [1.0044333] [-0.01007777]
# 1980 1.3232646e-05 [1.004225] [-0.00960422]
# 2000 1.201814e-05 [1.0040264] [-0.00915291]
